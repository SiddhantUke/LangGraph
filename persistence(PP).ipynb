# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from langgraph.checkpoint.memory import InMemorySaver

# %%
llm = ChatGroq(
    model = "llama-3.3-70b-versatile"
)

# %%
class JokeState(TypedDict):
    topic:str
    joke:str
    explaination: str

# %%
def generate_joke(state: JokeState):
    prompt = f'generate a joke on topic {state["topic"]}'
    response = llm.invoke(prompt).content
    return {'joke': response}

# %%
def generate_explanation(state: JokeState):
    prompt = f'write an explaination for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer= checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic': 'pizza'}, config = config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-f161-62b1-8002-da61bdaa13a7'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-08T22:34:56.073182+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-e6b9-638f-8001-aa7be1f1dcb7'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-f161-62b1-8002-da61bdaa13a7'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-08T22:34:56.073182+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-e6b9-638f-8001-aa7be1f1dcb7'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-e6b9-638f-8001-aa7be1f1dcb7'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-08T22:34:54.955815+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-ddd7-6ad2-8000-264438e29c0e'}}, tasks=(PregelTask(id='559dea13-cdc2-785c-2ba2-69c1b8aea23d', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-ddd7-6ad2-8000-264438e29c0e'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-08T22:34:54.024571+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-ddaa-6be0-bfff-2e21228e5d16'}}, tasks=(PregelTask(id='2628d708-4a35-70d6-6872-f89f910c4ef8', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-ddaa-6be0-bfff-2e21228e5d16'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-12-08T22:34:54.006166+00:00', parent_config=None, tasks=(PregelTask(id='119d844f-4757-1911-cd4f-96671d5ab741', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic': 'pasta'}, config = config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti refuse to get married?\n\nBecause it was afraid of getting tangled up in a relationship.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-f161-62b1-8002-da61bdaa13a7'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-08T22:34:56.073182+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-e6b9-638f-8001-aa7be1f1dcb7'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-f161-62b1-8002-da61bdaa13a7'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-08T22:34:56.073182+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-e6b9-638f-8001-aa7be1f1dcb7'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-e6b9-638f-8001-aa7be1f1dcb7'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-08T22:34:54.955815+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-ddd7-6ad2-8000-264438e29c0e'}}, tasks=(PregelTask(id='559dea13-cdc2-785c-2ba2-69c1b8aea23d', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-ddd7-6ad2-8000-264438e29c0e'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-08T22:34:54.024571+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-ddaa-6be0-bfff-2e21228e5d16'}}, tasks=(PregelTask(id='2628d708-4a35-70d6-6872-f89f910c4ef8', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-ddaa-6be0-bfff-2e21228e5d16'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-12-08T22:34:54.006166+00:00', parent_config=None, tasks=(PregelTask(id='119d844f-4757-1911-cd4f-96671d5ab741', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f06cc6e-7232-6cb1-8000-f71609e6cec5"}})
# Out:
# StateSnapshot(values={}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, metadata=None, created_at=None, parent_config=None, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-f161-62b1-8002-da61bdaa13a7'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-08T22:34:56.073182+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-e6b9-638f-8001-aa7be1f1dcb7'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-e6b9-638f-8001-aa7be1f1dcb7'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-08T22:34:54.955815+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-ddd7-6ad2-8000-264438e29c0e'}}, tasks=(PregelTask(id='559dea13-cdc2-785c-2ba2-69c1b8aea23d', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-ddd7-6ad2-8000-264438e29c0e'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-08T22:34:54.024571+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-ddaa-6be0-bfff-2e21228e5d16'}}, tasks=(PregelTask(id='2628d708-4a35-70d6-6872-f89f910c4ef8', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-ddaa-6be0-bfff-2e21228e5d16'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-12-08T22:34:54.006166+00:00', parent_config=None, tasks=(PregelTask(id='119d844f-4757-1911-cd4f-96671d5ab741', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f06cc6e-7232-6cb1-8000-f71609e6cec5", "checkpoint_ns": ""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0d487e-9fb0-6bc3-8000-07c52cf880a3'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d487e-9fb0-6bc3-8000-07c52cf880a3'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2025-12-08T22:47:45.970272+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, tasks=(PregelTask(id='7ee14077-ebd0-a59b-16f3-273df11d7b39', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-f161-62b1-8002-da61bdaa13a7'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-08T22:34:56.073182+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-e6b9-638f-8001-aa7be1f1dcb7'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-e6b9-638f-8001-aa7be1f1dcb7'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-08T22:34:54.955815+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-ddd7-6ad2-8000-264438e29c0e'}}, tasks=(PregelTask(id='559dea13-cdc2-785c-2ba2-69c1b8aea23d', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-ddd7-6ad2-8000-264438e29c0e'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-08T22:34:54.024571+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-ddaa-6be0-bfff-2e21228e5d16'}}, tasks=(PregelTask(id='2628d708-4a35-70d6-6872-f89f910c4ef8', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d4861-ddaa-6be0-bfff-2e21228e5d16'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-12-08T22:34:54.006166+00:00', parent_config=None, tasks=(PregelTask(id='119d844f-4757-1911-cd4f-96671d5ab741', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import time

class CrashState(TypedDict):
    input: str
    step1: str
    step2: str

# %%
def step_1(state: CrashState) -> CrashState:
    print("Step1 executed")
    return {"step1": "done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print("Step 2 hanging")
    time.sleep(1000)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print("Step 3 executed")
    return {"done": True}
